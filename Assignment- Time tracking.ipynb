# %% [markdown]
# # Programming Project 1 analysis using EDA tools
# - Name: Michael Zelaya
# - Date: 10/3/2023
# - Version: 1

# %% [markdown]
# ### Import Modules

# %% [markdown]
# ### Load the dataset and save it to a dataframe named 'df'
# ![image.png](attachment:image.png)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
import warnings

# Suppress UserWarnings
warnings.filterwarnings("ignore", category=UserWarning)
warnings.filterwarnings("ignore", category=FutureWarning)

# %%
df=pd.read_csv("MAZ_Timesheet_Project (4).csv")

# %%
df
# Out:
#    Initials      Date Course_id  Time (m)                    Summary
# 0         MZ   9/5/23   DS-160         75                       Class
# 1         MZ   9/5/23  ECON-410        75                       Class
# 2         MZ   9/5/23    DS-300        75                       Class
# 3         MZ   9/5/23    DS-300        60                    Group HW
# 4         MZ   9/5/23  MATH-430        60                    Group HW
# ..       ...      ...       ...       ...                         ...
# 73        MZ  9/28/23    DS-300        75                       Class
# 74        MZ  9/28/23  ECON-410       255           Studying for test
# 75        MZ  9/29/23  BUSA-245       155  Review + Studying for test
# 76        MZ  9/29/23    Unset         50                       Other
# 77        MZ  9/30/23  MATH-430       230  Review + Studying for test
#
# [78 rows x 5 columns]

# %% [markdown]
# ### Investigate your dataset

# %%
df.head(20)
# Out:
#    Initials      Date Course_id  Time (m)                  Summary
# 0         MZ   9/5/23   DS-160         75                     Class
# 1         MZ   9/5/23  ECON-410        75                     Class
# 2         MZ   9/5/23    DS-300        75                     Class
# 3         MZ   9/5/23    DS-300        60                  Group HW
# 4         MZ   9/5/23  MATH-430        60                  Group HW
# 5         MZ   9/5/23  BUSA-245        50           Chapter reading
# 6         MZ   9/6/23  BUSA-245        75                     Class
# 7         MZ   9/6/23  MATH-430        75                     Class
# 8         MZ   9/6/23    DS-300        60                  Group HW
# 9         MZ   9/6/23   DS-160        120           Podcast Summary
# 10        MZ   9/7/23   DS-160         75                     Class
# 11        MZ   9/7/23  ECON-410        75                     Class
# 12        MZ   9/7/23    DS-300        75                     Class
# 13        MZ   9/8/23  BUSA-245       240          HW & Ch. Reading
# 14        MZ   9/9/23  BUSA-245        50          HW & Ch. Reading
# 15        MZ   9/9/23  ECON-410        50      Review + Ch. Reading
# 16        MZ  9/10/23  MATH-430       170      Review + Ch. Reading
# 17        MZ  9/11/23  BUSA-245        75                     Class
# 18        MZ  9/11/23  MATH-430        75                     Class
# 19        MZ  9/11/23   DS-160         50  Pandas Practice Problems

# %%
df.tail()
# Out:
#    Initials      Date Course_id  Time (m)                    Summary
# 73        MZ  9/28/23    DS-300        75                       Class
# 74        MZ  9/28/23  ECON-410       255           Studying for test
# 75        MZ  9/29/23  BUSA-245       155  Review + Studying for test
# 76        MZ  9/29/23    Unset         50                       Other
# 77        MZ  9/30/23  MATH-430       230  Review + Studying for test

# %%
df.sample()
# Out:
#    Initials     Date Course_id  Time (m) Summary
# 10        MZ  9/7/23   DS-160         75    Class

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 78 entries, 0 to 77
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Initials   78 non-null     object
#  1   Date       78 non-null     object
#  2   Course_id  78 non-null     object
#  3   Time (m)   78 non-null     int64
#  4   Summary    78 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 3.2+ KB

# %%
df.columns
# Out:
# Index(['Initials ', 'Date', 'Course_id', 'Time (m)', 'Summary '], dtype='object')

# %% [markdown]
# ### Summary Statistics
# Calculate basic statistics for the 'Time (minutes)' column, such as mean, median, minimum, and maximum. This will give you an overview of how time is distributed across activities. use table and graphical representations
# ![image.png](attachment:image.png)

# %%
df.describe()
# Out:
#          Time (m)
# count   78.000000
# mean    86.217949
# std     47.291483
# min     30.000000
# 25%     63.750000
# 50%     75.000000
# 75%     75.000000
# max    265.000000

# %%
sns.boxplot(x='Course_id',y='Time (m)', data=df)
# Out:
# <Axes: xlabel='Course_id', ylabel='Time (m)'>

# %% [markdown]
# ### Create two new columns "day" and "day_name" using the "Date" column in which the day will represent the range of days
# ![image.png](attachment:image.png)

# %%
from datetime import datetime

datetime.now()
# Out:
# datetime.datetime(2023, 10, 5, 10, 43, 30, 239290)

# %%
df.head()
# Out:
#   Initials     Date Course_id  Time (m)  Summary
# 0        MZ  9/5/23   DS-160         75     Class
# 1        MZ  9/5/23  ECON-410        75     Class
# 2        MZ  9/5/23    DS-300        75     Class
# 3        MZ  9/5/23    DS-300        60  Group HW
# 4        MZ  9/5/23  MATH-430        60  Group HW

# %%
df['Date']=pd.to_datetime(df['Date'])

# %%
df['Day']=df['Date'].dt.day
df['Day']=range(1, len(df)+1)

# %%
df.head()
# Out:
#   Initials        Date Course_id  Time (m)  Summary   Day
# 0        MZ 2023-09-05   DS-160         75     Class    1
# 1        MZ 2023-09-05  ECON-410        75     Class    2
# 2        MZ 2023-09-05    DS-300        75     Class    3
# 3        MZ 2023-09-05    DS-300        60  Group HW    4
# 4        MZ 2023-09-05  MATH-430        60  Group HW    5

# %%
df['day_name']=df['Date'].dt.day_name()

# %%
df.head()
# Out:
#   Initials        Date Course_id  Time (m)  Summary   Day day_name
# 0        MZ 2023-09-05   DS-160         75     Class    1  Tuesday
# 1        MZ 2023-09-05  ECON-410        75     Class    2  Tuesday
# 2        MZ 2023-09-05    DS-300        75     Class    3  Tuesday
# 3        MZ 2023-09-05    DS-300        60  Group HW    4  Tuesday
# 4        MZ 2023-09-05  MATH-430        60  Group HW    5  Tuesday

# %% [markdown]
# ### Data Visualization:
# 1. Create a histogram or bar chart to visually represent the distribution of time spent.
# 2. Create a  bar chart to visually represent the distribution of time spent on different courses and comment on the course you spent most and least time
# ![image-3.png](attachment:image-3.png)

# %%
sns.histplot(x='Time (m)', data=df)
# Out:
# <Axes: xlabel='Time (m)', ylabel='Count'>

# %%
sns.barplot(x='Course_id', y='Time (m)', data=df, ci=False)
# Out:
# <Axes: xlabel='Course_id', ylabel='Time (m)'>

# %%
# I spent the most amount of time on my ECON-410 class.

# I spent the least amount of time on my unset. (no class- doing other things)

# %% [markdown]
# ### Activity Counts:
#
# Count the occurrences of each course in the dataset to see how often you engaged in each.

# %%
df['Course_id'].value_counts()
# Out:
# Course_id
# ECON-410    19
# BUSA-245    17
# DS-300      14
# DS-160      13
# MATH-430    12
# Unset        3
# Name: count, dtype: int64

# %%
sns.histplot(x='Course_id',data=df,stat='count')
# Out:
# <Axes: xlabel='Course_id', ylabel='Count'>

# %% [markdown]
# ### Time Trends:
#
# Plot a line chart to visualize how time spent on activities changes over the observed days.
# ![image.png](attachment:image.png)

# %%
sns.lineplot(x='Day',y='Time (m)',data=df, hue='Course_id', ci=False)
# Out:
# <Axes: xlabel='Day', ylabel='Time (m)'>

# %% [markdown]
# ### Course Analysis: ???
#
# For each course ex.(DS 160, CS 150, CS 440), calculate the total time spent. Which course received the most time, and which received the least?
# - Sample print statement: Total time spent on CS160: 180 min

# %%
DS160= df.query('Course_id=="DS-160"')['Time (m)'].sum()
print(f'Total time spent on DS-160: {DS160}')
# Out:
# Total time spent on DS-160: 0

# %%
df['Course_id'].value_counts()
# Out:
# Course_id
# ECON-410    19
# BUSA-245    17
# DS-300      14
# DS-160      13
# MATH-430    12
# Unset        3
# Name: count, dtype: int64

# %%
df.query('Course_id=="DS-160"')
# Out:
# Empty DataFrame
# Columns: [Initials , Date, Course_id, Time (m), Summary , Day, day_name]
# Index: []

# %%
ECON410= df.query('Course_id=="ECON-410"')['Time (m)'].sum()
print(f'Total time spent on ECON-410: {ECON410}')
# Out:
# Total time spent on ECON-410: 1980

# %%
DS300= df.query('Course_id=="DS-300"')['Time (m)'].sum()
print(f'Total time spent on DS-300: {DS300}')
# Out:
# Total time spent on DS-300: 1075

# %%
MATH430= df.query('Course_id=="MATH-430"')['Time (m)'].sum()
print(f'Total time spent on MATH-430: {MATH430}')
# Out:
# Total time spent on MATH-430: 1135

# %%
BUSA245= df.query('Course_id=="BUSA-245"')['Time (m)'].sum()
print(f'Total time spent on BUSA-245: {BUSA245}')
# Out:
# Total time spent on BUSA-245: 1430

# %%
Unset= df.query('Course_id=="Unset"')['Time (m)'].sum()
print(f'Total time spent on Unset: {Unset}')
# Out:
# Total time spent on Unset: 0

# %%
# My ECON-410 class recieved the most time, while DS-300 or DS-160 recieved the least amount of time.

# %% [markdown]
# ### Correlations:
# - Examine whether there are any correlations between the day and the time spent. For example, do you spend more time on courses over days or less.
# ![image.png](attachment:image.png)

# %%
Corr=df[['Day','Time (m)']].corr()
cols=['Day','Time (m)']

print(Corr)
sns.heatmap(Corr,xticklabels=cols, yticklabels=cols,annot=True)
# Out:
#                Day  Time (m)
# Day       1.000000  0.225862
# Time (m)  0.225862  1.000000
# <Axes: >

# %% [markdown]
# ### Reflection:

# %% [markdown]
# ### From this time tracking assignment, I learned many different ways to investigate my own data. For instance, creating different visual representations like making a box plot, histogram, bar chart, line chart, and a heat map correlation table. As well, I learned how to add a 'Day' and 'Day_name' columns in my data and lastly learned how to analyze time spent on each of my classes.
